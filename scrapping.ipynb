# %%
#war
from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains


driver = webdriver.Chrome()


driver.get('https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres=war')

driver.maximize_window()
time.sleep(3)


titles = []
ratings = []
votings = []
durations = []


def load_more():
    try:
        
        load_more_button = driver.find_element(By.XPATH,'//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/div[2]/div/span/button/span/span')
        
        ActionChains(driver).move_to_element(load_more_button).perform()
        load_more_button.click()
        time.sleep(3)
        return True
    except Exception as e:
        return False


while load_more():
    
    movie_items = driver.find_elements(By.XPATH, "//*[@id='__next']/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li")

    
    for movie_item in movie_items:
        try:
            title = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/div[1]/a/h3').text
            rating = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/span/div/span/span[1]').text
            voting = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/span/div/span/span[2]').text
            duration = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/div[2]/span[2]').text
            time.sleep(1)

            titles.append(title)
            ratings.append(rating)
            votings.append(voting)
            durations.append(duration)

        except Exception as e:
            
            continue

print("No more elements to load.")


df = pd.DataFrame({
    'Title': titles,
    'Rating': ratings,
    'Votes': votings,
    'Duration': durations
})


df['Genre'] = 'War'


print(df)
df.to_csv("War.csv")


driver.quit()
# Out:
# No more elements to load.
#                                         Title Rating    Votes Duration Genre
# 0                             1. William Tell    5.7   (1.8K)   2h 13m   War
# 1    2. The Ministry of Ungentlemanly Warfare    6.8   (132K)    2h 2m   War
# 2                     3. The Six Triple Eight    6.7    (25K)    2h 7m   War
# 3                             4. Dirty Angels    4.3   (3.2K)   1h 44m   War
# 4                       5. My Dead Friend Zoe    6.8   (1.5K)   1h 43m   War
# ..                                        ...    ...      ...      ...   ...
# 144                       111. Los indomables    6.5      (9)   1h 46m   War
# 145           114. Por ti, Portugal, eu juro!    7.6      (5)   1h 38m   War
# 146                       115. Krigsvarsleren    7.4      (7)      55m   War
# 147               119. Dosije Kosovo - Pogrom    7.6      (5)   1h 49m   War
# 148                     120. On Moral Grounds    8.4      (7)   1h 14m   War
#
# [149 rows x 5 columns]

# %%
#musical

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains


driver = webdriver.Chrome()


driver.get('https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres=musical')

driver.maximize_window()
time.sleep(3)


titles = []
ratings = []
votings = []
durations = []


def load_more():
    try:
        
        load_more_button = driver.find_element(By.XPATH,'//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/div[2]/div/span/button/span/span')
        
        ActionChains(driver).move_to_element(load_more_button).perform()
        load_more_button.click()
        time.sleep(3)
        return True
    except Exception as e:
        return False


while load_more():
    
    movie_items = driver.find_elements(By.XPATH, "//*[@id='__next']/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li")

    
    for movie_item in movie_items:
        try:
            title = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/div[1]/a/h3').text
            rating = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/span/div/span/span[1]').text
            voting = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/span/div/span/span[2]').text
            duration = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/div[2]/span[2]').text
            time.sleep(1)

            titles.append(title)
            ratings.append(rating)
            votings.append(voting)
            durations.append(duration)

        except Exception as e:
            
            continue

print("No more elements to load.")


df = pd.DataFrame({
    'Title': titles,
    'Rating': ratings,
    'Votes': votings,
    'Duration': durations
})


df['Genre'] = 'Musical'


print(df)
df.to_csv("Musical.csv")


driver.quit()
# Out:
# No more elements to load.
#                                                  Title Rating    Votes  \
# 0                                           1. Moana 2    6.7    (89K)
# 1                                            2. Wicked    7.5   (144K)
# 2                                      3. Emilia Pérez    5.4    (85K)
# 3                             4. Mufasa: The Lion King    6.6    (48K)
# 4                                        5. Better Man    7.6    (23K)
# ..                                                 ...    ...      ...
# 187                               103. Peaceful Lights    9.8     (17)
# 188  106. El musical de los 80s y los 90s. La película    6.1      (8)
# 189  130. The Clashing Elements: Saviors of the Mul...    6.6      (7)
# 190                                   132. Iyus Jenius    9.0      (7)
# 191                                        136. Rangde    8.6      (6)
#
#     Duration    Genre
# 0     1h 40m  Musical
# 1     2h 40m  Musical
# 2     2h 12m  Musical
# 3     1h 58m  Musical
# 4     2h 15m  Musical
# ..       ...      ...
# 187   1h 26m  Musical
# 188   1h 20m  Musical
# 189   1h 31m  Musical
# 190   1h 22m  Musical
# 191   2h 23m  Musical
#
# [192 rows x 5 columns]

# %%
#history

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains


driver = webdriver.Chrome()


driver.get('https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres=history')

driver.maximize_window()
time.sleep(3)


titles = []
ratings = []
votings = []
durations = []


def load_more():
    try:
        
        load_more_button = driver.find_element(By.XPATH,'//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/div[2]/div/span/button/span/span')
        
        ActionChains(driver).move_to_element(load_more_button).perform()
        load_more_button.click()
        time.sleep(3)
        return True
    except Exception as e:
        return False


while load_more():
    
    movie_items = driver.find_elements(By.XPATH, "//*[@id='__next']/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li")

    
    for movie_item in movie_items:
        try:
            title = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/div[1]/a/h3').text
            rating = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/span/div/span/span[1]').text
            voting = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/span/div/span/span[2]').text
            duration = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/div[2]/span[2]').text
            time.sleep(1)

            titles.append(title)
            ratings.append(rating)
            votings.append(voting)
            durations.append(duration)

        except Exception as e:
            
            continue

print("No more elements to load.")


df = pd.DataFrame({
    'Title': titles,
    'Rating': ratings,
    'Votes': votings,
    'Duration': durations
})


df['Genre'] = 'History'


print(df)
df.to_csv("History.csv")


driver.quit()
# Out:
# No more elements to load.
#                                             Title Rating    Votes Duration  \
# 0                               1. I'm Still Here    8.4    (96K)   2h 17m
# 1                               2. The Apprentice    7.1    (51K)    2h 2m
# 2                                 3. William Tell    5.7   (1.8K)   2h 13m
# 3                                  4. September 5    7.1    (20K)   1h 35m
# 4                               5. Saturday Night    6.9    (29K)   1h 49m
# ..                                            ...    ...      ...      ...
# 916                   278. Xun zhao tang de zhang    7.8     (16)   1h 33m
# 917  289. Georges Pompidou, la cruauté du pouvoir    6.2      (6)   1h 44m
# 918                          292. The Man Outside    7.4     (10)   1h 10m
# 919                 296. The Canal Map of Britain    6.8     (10)      59m
# 920                         297. On Moral Grounds    8.4      (7)   1h 14m
#
#        Genre
# 0    History
# 1    History
# 2    History
# 3    History
# 4    History
# ..       ...
# 916  History
# 917  History
# 918  History
# 919  History
# 920  History
#
# [921 rows x 5 columns]

# %%
#Fantasy

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains


driver = webdriver.Chrome()


driver.get('https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres=fantasy')

driver.maximize_window()
time.sleep(3)


titles = []
ratings = []
votings = []
durations = []


def load_more():
    try:
        
        load_more_button = driver.find_element(By.XPATH,'//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/div[2]/div/span/button/span/span')
        
        ActionChains(driver).move_to_element(load_more_button).perform()
        load_more_button.click()
        time.sleep(3)
        return True
    except Exception as e:
        return False


while load_more():
    
    movie_items = driver.find_elements(By.XPATH, "//*[@id='__next']/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li")

    
    for movie_item in movie_items:
        try:
            title = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/div[1]/a/h3').text
            rating = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/span/div/span/span[1]').text
            voting = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/span/div/span/span[2]').text
            duration = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/div[2]/span[2]').text
            time.sleep(1)

            titles.append(title)
            ratings.append(rating)
            votings.append(voting)
            durations.append(duration)

        except Exception as e:
            
            continue

print("No more elements to load.")


df = pd.DataFrame({
    'Title': titles,
    'Rating': ratings,
    'Votes': votings,
    'Duration': durations
})


df['Genre'] = 'Fantasy'


print(df)
df.to_csv("Fantasy.csv")


driver.quit()
# Out:
# No more elements to load.
#                                              Title Rating    Votes Duration  \
# 0                                       1. Moana 2    6.7    (90K)   1h 40m
# 1                                          2. Flow    7.9    (61K)   1h 25m
# 2                                     3. Nosferatu    7.3   (180K)   2h 12m
# 3                                        4. Wicked    7.5   (144K)   2h 40m
# 4                          5. Sonic the Hedgehog 3    6.9    (53K)   1h 50m
# ...                                            ...    ...      ...      ...
# 2464                                     424. LUDA    7.2      (6)   1h 26m
# 2465  438. Kan dao ling hun de na zhi yan shi gong    3.3     (12)    2h 4m
# 2466                                 459. Cageling    5.9      (8)    1h 9m
# 2467                               461. Lucid Love    8.6     (29)   1h 11m
# 2468                            472. The Blinkless    7.8     (12)      59m
#
#         Genre
# 0     Fantasy
# 1     Fantasy
# 2     Fantasy
# 3     Fantasy
# 4     Fantasy
# ...       ...
# 2464  Fantasy
# 2465  Fantasy
# 2466  Fantasy
# 2467  Fantasy
# 2468  Fantasy
#
# [2469 rows x 5 columns]

# %%
#Animation

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains


driver = webdriver.Chrome()


driver.get('https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres=animation')

driver.maximize_window()
time.sleep(3)


titles = []
ratings = []
votings = []
durations = []


def load_more():
    try:
        
        load_more_button = driver.find_element(By.XPATH,'//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/div[2]/div/span/button/span/span')
        
        ActionChains(driver).move_to_element(load_more_button).perform()
        load_more_button.click()
        time.sleep(3)
        return True
    except Exception as e:
        return False


while load_more():
    
    movie_items = driver.find_elements(By.XPATH, "//*[@id='__next']/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li")

    
    for movie_item in movie_items:
        try:
            title = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/div[1]/a/h3').text
            rating = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/span/div/span/span[1]').text
            voting = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/span/div/span/span[2]').text
            duration = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/div[2]/span[2]').text
            time.sleep(1)

            titles.append(title)
            ratings.append(rating)
            votings.append(voting)
            durations.append(duration)

        except Exception as e:
            
            continue

print("No more elements to load.")


df = pd.DataFrame({
    'Title': titles,
    'Rating': ratings,
    'Votes': votings,
    'Duration': durations
})


df['Genre'] = 'Animation'


print(df)
df.to_csv("Animation.csv")


driver.quit()
# Out:
# No more elements to load.
#                                                   Title Rating    Votes  \
# 0                                            1. Moana 2    6.7    (89K)
# 1                                               2. Flow    7.9    (61K)
# 2                                     3. The Wild Robot    8.2   (153K)
# 3                              4. Mufasa: The Lion King    6.6    (48K)
# 4     5. The Lord of the Rings: The War of the Rohirrim    6.3    (28K)
# ...                                                 ...    ...      ...
# 1491               309. Ekip: Siberay - Günes Firtinasi    6.0     (14)
# 1492    310. Uma Musume: Pretty Derby - Road to the Top    6.0      (6)
# 1493                                          311. LUDA    7.2      (6)
# 1494                314. Bie ba zuo wen dang hui shi er    7.2     (10)
# 1495                                  336. Sirds likums    6.8     (17)
#
#      Duration      Genre
# 0      1h 40m  Animation
# 1      1h 25m  Animation
# 2      1h 42m  Animation
# 3      1h 58m  Animation
# 4      2h 14m  Animation
# ...       ...        ...
# 1491   1h 12m  Animation
# 1492   1h 38m  Animation
# 1493   1h 26m  Animation
# 1494   1h 29m  Animation
# 1495    1h 5m  Animation
#
# [1496 rows x 5 columns]

# %%
#Mystery

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains


driver = webdriver.Chrome()


driver.get('https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres=mystery')

driver.maximize_window()
time.sleep(3)


titles = []
ratings = []
votings = []
durations = []


def load_more():
    try:
        
        load_more_button = driver.find_element(By.XPATH,'//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/div[2]/div/span/button/span/span')
        
        ActionChains(driver).move_to_element(load_more_button).perform()
        load_more_button.click()
        time.sleep(3)
        return True
    except Exception as e:
        return False


while load_more():
    
    movie_items = driver.find_elements(By.XPATH, "//*[@id='__next']/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li")

    
    for movie_item in movie_items:
        try:
            title = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/div[1]/a/h3').text
            rating = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/span/div/span/span[1]').text
            voting = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/span/div/span/span[2]').text
            duration = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/div[2]/span[2]').text
            time.sleep(1)

            titles.append(title)
            ratings.append(rating)
            votings.append(voting)
            durations.append(duration)

        except Exception as e:
            
            continue

print("No more elements to load.")


df = pd.DataFrame({
    'Title': titles,
    'Rating': ratings,
    'Votes': votings,
    'Duration': durations
})


df['Genre'] = 'Mystery'


print(df)
df.to_csv("Mystery.csv")


driver.quit()
# Out:
# No more elements to load.
#                                Title Rating    Votes Duration    Genre
# 0                       1. Nosferatu    7.3   (180K)   2h 12m  Mystery
# 1                            2. Trap    5.8   (131K)   1h 45m  Mystery
# 2                     3. Blink Twice    6.5   (101K)   1h 42m  Mystery
# 3                         4. Smile 2    6.7    (98K)    2h 7m  Mystery
# 4              5. Paddington in Peru    6.7    (18K)   1h 46m  Mystery
# ...                              ...    ...      ...      ...      ...
# 3882         570. Khoroshie devochki    8.2      (5)   1h 31m  Mystery
# 3883          586. It's Not the Time    6.6     (21)   1h 18m  Mystery
# 3884        596. Not One and Not Two    5.7      (6)   1h 12m  Mystery
# 3885             624. Once Passed On    6.6      (6)   1h 31m  Mystery
# 3886  633. Okhota na russkogo geniya    2.6      (7)   1h 11m  Mystery
#
# [3887 rows x 5 columns]

# %%
#Sport

from selenium import webdriver
from selenium.webdriver.common.by import By
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd
from selenium.webdriver.common.action_chains import ActionChains


driver = webdriver.Chrome()


driver.get('https://www.imdb.com/search/title/?title_type=feature&release_date=2024-01-01,2024-12-31&genres=sport')

driver.maximize_window()
time.sleep(3)


titles = []
ratings = []
votings = []
durations = []


def load_more():
    try:
        
        load_more_button = driver.find_element(By.XPATH,'//*[@id="__next"]/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/div[2]/div/span/button/span/span')
        
        ActionChains(driver).move_to_element(load_more_button).perform()
        load_more_button.click()
        time.sleep(3)
        return True
    except Exception as e:
        return False


while load_more():
    
    movie_items = driver.find_elements(By.XPATH, "//*[@id='__next']/main/div[2]/div[3]/section/section/div/section/section/div[2]/div/section/div[2]/div[2]/ul/li")

    
    for movie_item in movie_items:
        try:
            title = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/div[1]/a/h3').text
            rating = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/span/div/span/span[1]').text
            voting = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/span/div/span/span[2]').text
            duration = movie_item.find_element(By.XPATH, './div/div/div/div[1]/div[2]/div[2]/span[2]').text
            time.sleep(1)

            titles.append(title)
            ratings.append(rating)
            votings.append(voting)
            durations.append(duration)

        except Exception as e:
            
            continue

print("No more elements to load.")


df = pd.DataFrame({
    'Title': titles,
    'Rating': ratings,
    'Votes': votings,
    'Duration': durations
})


df['Genre'] = 'Sport'


print(df)
df.to_csv("Sport.csv")


driver.quit()
# Out:
# No more elements to load.
#                                                  Title Rating    Votes  \
# 0                                 1. Queen of the Ring    7.0    (841)
# 1                                   2. The Fire Inside    6.7   (2.2K)
# 2                                       3. Unstoppable    6.8   (3.9K)
# 3                           4. Young Woman and the Sea    7.5    (17K)
# 4                                   5. Arthur the King    7.0    (34K)
# ..                                                 ...    ...      ...
# 608  212. Zlatan Ibrahimovic hyllningsmatch (Sweden...    6.6      (6)
# 609                     223. Gyakorlat teszi a mestert    6.1     (15)
# 610                226. Is University Really Worth It?    5.2     (12)
# 611                                   232. Quote 10.35    8.0     (24)
# 612                     234. ¡Qué suerte hemos tenido!    7.5     (16)
#
#     Duration  Genre
# 0     2h 20m  Sport
# 1     1h 49m  Sport
# 2     1h 56m  Sport
# 3      2h 9m  Sport
# 4     1h 47m  Sport
# ..       ...    ...
# 608   2h 50m  Sport
# 609      46m  Sport
# 610       1h  Sport
# 611      35m  Sport
# 612    1h 2m  Sport
#
# [613 rows x 5 columns]

# %%
import pandas as pd


file1 = "C:/Users/staru/Desktop/imdb project/web_scrap/Animation.csv"
file2 = "C:/Users/staru/Desktop/imdb project/web_scrap/Fantasy.csv"
file3 = "C:/Users/staru/Desktop/imdb project/web_scrap/History.csv"
file4 = "C:/Users/staru/Desktop/imdb project/web_scrap/Musical.csv"
file5 = "C:/Users/staru/Desktop/imdb project/web_scrap/Mystery.csv"
file6 = "C:/Users/staru/Desktop/imdb project/web_scrap/Sport.csv"
file7 = "C:/Users/staru/Desktop/imdb project/web_scrap/War.csv"

df1 = pd.read_csv(file1)
df2 = pd.read_csv(file2)
df3 = pd.read_csv(file3)
df4 = pd.read_csv(file4)
df5 = pd.read_csv(file5)
df6 = pd.read_csv(file6)
df7 = pd.read_csv(file7)

combined_df = pd.concat([df1, df2,df3,df4,df5,df6,df7], ignore_index=True)

combined_df.to_csv('Movie_details.csv', index=False)

print("CSV files combined and saved successfully.")



df = pd.read_csv('Movie_details.csv')

df = df.iloc[:, 1:]
df.to_csv('modified_file.csv', index=False)
# Out:
# CSV files combined and saved successfully.

# %%
import pandas as pd
import re

file_path = "C:/Users/staru/Desktop/imdb project/web_scrap/modified_file.csv"
df = pd.read_csv(file_path)

def clean_votes(vote):
    vote = str(vote).strip()
    vote = re.sub(r'[()]', '', vote)
    
    if 'k' in vote.lower():  
        vote = vote.lower().replace('k', '')  
        try:
            return float(vote) * 1000
        except ValueError:
            return None  
    try:
        return float(vote)  
    except ValueError:
        return None 
    
df['Votes'] = df['Votes'].apply(clean_votes)

output_file = "C:/Users/staru/Desktop/imdb project/web_scrap/modified_file.csv"
df.to_csv(output_file, index=False)

# %%
import pandas as pd

file_path = "C:/Users/staru/Desktop/imdb project/web_scrap/modified_file.csv"
df = pd.read_csv(file_path)

def convert_duration_to_minutes(duration):
    if 'h' in str(duration):
        hours, minutes = str(duration).split('h')
        minutes = minutes.replace('m', '').strip()
        return int(hours) * 60 + int(minutes) if minutes else int(hours) * 60
    elif 'm' in str(duration):
        return int(str(duration).replace('m', '').strip())
    return 0

df['Duration'] = df['Duration'].apply(convert_duration_to_minutes)

output_file = "C:/Users/staru/Desktop/imdb project/web_scrap/modified_file.csv"
df.to_csv(output_file, index=False)

# %%
import pandas as pd

# Load the CSV file
df = pd.read_csv("C:/Users/staru/Desktop/imdb project/web_scrap/modified_file.csv")

# Remove the row where the 'Title' column is "Teenieping of Love"
df = df[df['Title'] != "Teenieping of Love"]

# Save the modified DataFrame back to the CSV file
df.to_csv("C:/Users/staru/Desktop/imdb project/web_scrap/modified_file.csv", index=False)

print("Row with 'Teenieping of Love' has been removed and the cleaned file is saved.")
# Out:
# Row with 'Teenieping of Love' has been removed and the cleaned file is saved.
